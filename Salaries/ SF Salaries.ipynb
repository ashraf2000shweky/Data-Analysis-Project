# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Salaries.csv')
data
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4820\3527810576.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
data.head(10) # أول عشرة سطور
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
data.tail(10) # أخر عشرة سطور
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
data.shape
# Out:
# (148654, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
# إسقاط الأعمدة المشبعة بالقيم المفقودة
data.drop(['Id','Notes','Benefits','Agency'],axis=1,inplace=True)

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay   TotalPay  TotalPayBenefits  \
# ...

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'TotalPay', 'TotalPayBenefits', 'Year', 'Status'],
#       dtype='object')

# %%
# أكثر عشر وظائف تكراراً
data['JobTitle'].value_counts().head(10)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: JobTitle, dtype: int64

# %%
# عدد الوظائف
data['JobTitle'].nunique()
# Out:
# 2159

# %%
# CAPTAIN عدد الذين لديهم وظيفة 
len(data[data['JobTitle'].str.contains('CAPTAIN',case=False)])
# Out:
# 552

# %%
data[data['JobTitle'].str.contains('data',case=False)]
# Out:
#                   EmployeeName                    JobTitle   BasePay  \
# 29930    NELVYNE MICKELS-SMITH  SENIOR DATA ENTRY OPERATOR   16565.0
# 67296    Nelvyne Mickels-Smith  Senior Data Entry Operator  11162.36
# 105369  Nelvyne  Mickels-Smith  Senior Data Entry Operator       NaN
#
#        OvertimePay OtherPay  TotalPay  TotalPayBenefits  Year Status
# 29930          0.0   204.68  16769.68          16769.68  2011    NaN
# 67296          0.0   133.86  11296.22          17720.15  2012    NaN
# 105369         0.0  3991.07   3991.07          12419.45  2013    NaN

# %%
# FIRE DEPARTMENTأسماء الموظفين في  
# csv تم الحفظ في ملف  
data[data['JobTitle'].str.contains('FIRE DEPARTMENT',case=False)]['EmployeeName']\
.to_csv('FIRE DEPARTMENT.csv')

# %%
data = data[~(data['BasePay'] == 'Not Provided')]

# %%
data['BasePay'] = data['BasePay'].astype(float)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4820\1799940223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['BasePay'] = data['BasePay'].astype(float)

# %%
data['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
data['BasePay'].median()
# Out:
# 65007.45

# %%
data['BasePay'].std()
# Out:
# 42764.63549525958

# %%
data['BasePay'].hist()
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'TotalPay', 'TotalPayBenefits', 'Year', 'Status'],
#       dtype='object')

# %%
data['EmployeeName'].replace('Not provided',np.nan,inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4820\1629511567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EmployeeName'].replace('Not provided',np.nan,inplace=True)

# %%
# معرفة وظيفة الموظف 
data[data['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
# راتب موظف المختار 
data[data['EmployeeName']=='ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
# الموظف ذو الراتب الأولى المختار 
data[data['BasePay']==319275.01]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
# متوسط الرواتب في السنة
data.groupby('Year').mean()
# Out:
#            BasePay      TotalPay  TotalPayBenefits
# Year
# 2011  63595.956517  71744.103871      71744.103871
# 2012  65436.406857  74113.262265     100553.229232
# 2013  69630.030216  77611.443142     101440.519714
# 2014  66564.421924  75471.836912     100261.438668

# %%
# متوسط أعلى دخل  خمسة وظايف في السنة 
data.groupby('JobTitle').mean()['BasePay'].head().sort_values(ascending=False)
# Out:
# JobTitle
# ACUPUNCTURIST                  66374.400000
# ACPO,JuvP, Juv Prob (SFERS)    62290.780000
# ACCOUNTANT                     46643.172000
# ACCOUNT CLERK                  43300.806506
# ACCOUNTANT INTERN              28732.663958
# Name: BasePay, dtype: float64

# %%
# متوسط الدخل السنوي للذين يعملون في قطاع المحاسبة 
data[data['JobTitle'].str.contains('ACCOUNT',case=False)]['BasePay'].mean()
# Out:
# 61614.40233000924

# %%
# أكثر خمسة وظايف إنتشاراً
data['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
# إستخلاص كل سنة على إنفراد
df_11 = data[data['Year']==2011]
df_12 = data[data['Year']==2012]
df_13 = data[data['Year']==2013]
df_14 = data[data['Year']==2014]

# %%
# عرض مشترك 
display(df_11,df_12,df_13,df_14)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 36154       SERENA HUGHES              SWIMMING INSTRUCTOR/POOL LIFEGUARD
# 36155        JOE BROWN JR                                TRANSIT OPERATOR
# 36156      PAULETTE ADAMS      STATIONARY ENGINEER, WATER TREATMENT PLANT
# 36157       KAUKAB MOHSIN                                TRANSIT OPERATOR
# 36158  JOSEPHINE MCCREARY                                      MANAGER IV
#
#          BasePay OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
# أخذ وظيفة معينة والعمل عليها 
df_11_chief = df_11[df_11['JobTitle'].str.contains('CHIEF',case=False)]

# %%
# أعلى راتب 
df_11_chief['BasePay'].max()
# Out:
# 285262.0

# %%
# تفاصيل سطر أعلى راتب 
df_11_chief[df_11_chief['BasePay'] == 285262.0]
# Out:
#          EmployeeName                                JobTitle   BasePay  \
# 9  JOANNE HAYES-WHITE  CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.0
#
#   OvertimePay  OtherPay   TotalPay  TotalPayBenefits  Year Status
# 9         0.0  17115.73  302377.73         302377.73  2011    NaN

# %%
# متوسط الرواتب 
df_11_chief.mean().to_frame()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4820\3032979194.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_11_chief.mean().to_frame()
#                               0
# BasePay           125953.031618
# OvertimePay        10518.847255
# OtherPay           15804.611667
# TotalPay          152276.490539
# TotalPayBenefits  152276.490539
# Year                2011.000000
# Status                      NaN

# %%
df_11_chief.median().to_frame()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4820\3658926824.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_11_chief.median().to_frame()
#                            0
# BasePay           112686.125
# OvertimePay            0.000
# OtherPay            7509.065
# TotalPay          143117.125
# TotalPayBenefits  143117.125
# Year                2011.000
# Status                   NaN

# %%
# الإنحراف المعياري عالي 
df_11_chief.std().to_frame()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4820\2313098969.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_11_chief.std().to_frame()
#                              0
# BasePay           57368.644496
# OvertimePay       19813.090797
# OtherPay          28783.544723
# TotalPay          70963.450428
# TotalPayBenefits  70963.450428
# Year                  0.000000
# Status                     NaN

# %%
df_11_chief['BasePay'].hist()
# Out:
# <AxesSubplot:>

# %%
df_11_chief['BasePay'].describe()
# Out:
# count       204.000000
# mean     125953.031618
# std       57368.644496
# min           0.000000
# 25%       91596.660000
# 50%      112686.125000
# 75%      174100.132500
# max      285262.000000
# Name: BasePay, dtype: float64

# %%
df_12_chief = df_12[df_12['JobTitle'].str.contains('CHIEF',case=False)]

# %%
df_13_chief = df_13[df_13['JobTitle'].str.contains('CHIEF',case=False)]

# %%
df_14_chief = df_14[df_14['JobTitle'].str.contains('CHIEF',case=False)]

# %%
x = df_11_chief.describe()

# %%
y = df_12_chief.describe()

# %%
z = df_13_chief.describe()

# %%
w = df_14_chief.describe()

# %%
# مقارنة بين السنوات بالنسبة لوظيفة الطاهي 
display(x,y,z,w)
# Out:
#              BasePay       TotalPay  TotalPayBenefits    Year
# count     204.000000     204.000000        204.000000   204.0
# mean   125953.031618  152276.490539     152276.490539  2011.0
# std     57368.644496   70963.450428      70963.450428     0.0
# min         0.000000    1213.240000       1213.240000  2011.0
# 25%     91596.660000  106683.997500     106683.997500  2011.0
# 50%    112686.125000  143117.125000     143117.125000  2011.0
# 75%    174100.132500  198273.387500     198273.387500  2011.0
# max    285262.000000  326373.190000     326373.190000  2011.0
#              BasePay       TotalPay  TotalPayBenefits    Year
# count     141.000000     141.000000        141.000000   141.0
# mean   139608.260000  168720.268227     212636.570922  2012.0
# std     64627.119921   75995.568303      87563.082107     0.0
# min         0.000000    9077.000000      10452.520000  2012.0
# 25%     87145.950000  102789.620000     142880.360000  2012.0
# ...

# %% [markdown]
# <h2> تسطيع العمل الكثير والكثير بهذه البيانات من خلال تحديد الوظيفة وتحليل هذه الوظيفة
