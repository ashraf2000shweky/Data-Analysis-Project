# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('supermarket_sales.xlsx')

# %%
data.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data['Product line'].value_counts()
# Out:
# Fashion_accessories       178
# Food_and_beverages        174
# Electronic_accessories    170
# Sports_and_travel         166
# Home_and_lifestyle        160
# Health_and_beauty         152
# Name: Product line, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
sns.countplot(y='Product line',data=data) # y

plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line',hue='Gender',data=data)  
plt.legend(bbox_to_anchor=(1.1,1),fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Product line',hue='Gender',data=data)
plt.xlabel('Product line',fontsize = 20,loc='right',labelpad = 15 ) 
plt.ylabel('Count',fontsize = 20)
plt.legend(bbox_to_anchor=(1.2,1),fontsize=15)  
plt.xticks(fontsize=12)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total',data=data,estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(y='Product line',x='Total',data=data)
plt.ylabel('Product line',fontsize = 20,labelpad = 20 )
plt.xlabel('Total',fontsize = 20,labelpad = 20 )
# Out:
# Text(0.5, 0, 'Total')

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
x =data['Product line'].sort_values()
x.unique()
# Out:
# array(['Electronic_accessories', 'Fashion_accessories',
#        'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
#        'Sports_and_travel'], dtype=object)

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data,order=x.unique())
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data,ci=None)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data,ci=None,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
pd.DataFrame(data.groupby(['Product line','Gender'])['Total'].sum().sort_index())
# Out:
#                                     Total
# Product line           Gender
# Electronic_accessories Female  27102.0225
#                        Male    27235.5090
# Fashion_accessories    Female  30437.4000
#                        Male    23868.4950
# Food_and_beverages     Female  33170.9175
#                        Male    22973.9265
# Health_and_beauty      Female  18560.9865
#                        Male    30632.7525
# Home_and_lifestyle     Female  30036.8775
#                        Male    23825.0355
# Sports_and_travel      Female  28574.7210
#                        Male    26548.1055

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data,estimator=np.sum  )
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
pd.DataFrame(data.groupby(['Product line','Gender'])['Total'].mean())
# Out:
#                                     Total
# Product line           Gender
# Electronic_accessories Female  322.643125
#                        Male    316.691965
# Fashion_accessories    Female  317.056250
#                        Male    291.079207
# Food_and_beverages     Female  368.565750
#                        Male    273.499125
# Health_and_beauty      Female  290.015414
#                        Male    348.099460
# Home_and_lifestyle     Female  380.213639
#                        Male    294.136241
# Sports_and_travel      Female  324.712739
#                        Male    340.360327

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Total' ,hue='Gender',data=data,ci=None,estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
sns.boxplot(y='Total',data=data,width=0.5,)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.boxplot(x='Payment',y='Total',data=data,fliersize=5)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.boxplot(x='Payment',y='Total',hue='Gender',data=data)
plt.legend(bbox_to_anchor=(1.1,1),fontsize=10)

# %%
sns.boxplot(y='Payment',x='Total',hue='Gender',showmeans=True
            ,meanprops={'marker':'o','markerfacecolor':'w','markersize':7,'markeredgecolor':'k'}
            ,data=data)
plt.legend(bbox_to_anchor=(1.1,1),fontsize=10)
plt.show()

# %%
sns.boxplot(y='Payment',x='Total',hue='Gender',showmeans=True
            ,meanprops={'marker':'o','markerfacecolor':'w','markersize':7,'markeredgecolor':'k'}
            ,data=data
            ,palette='gist_earth'
            ,linewidth=1.7)
plt.legend(bbox_to_anchor=(1.1,1),fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=data)
plt.xticks(rotation = 50, size=10)
plt.show()

# %%
sns.stripplot(data=data,y='Total')
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.stripplot(data=data,y='Total',jitter=0.2)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.stripplot(data=data,y='Total',jitter=0.2,linewidth=0.2)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.stripplot(data=data , y='Total',hue='Gender',x='Payment',jitter=0.2)
plt.legend(bbox_to_anchor=(1.1,1),fontsize=10)

# %%
sns.stripplot(data=data , y='Total',hue='Gender',x='Payment',jitter=0.2,dodge=True)
plt.legend(bbox_to_anchor=(1.1,1),fontsize=10)

# %%
sns.stripplot(data=data , y='Total',x='Payment', linewidth=0.2,jitter=0.2)
sns.boxplot(data=data , y='Total',x='Payment',color='gray',linewidth=2)
plt.show()

# %%
data = data[['Gender','Payment','Unit price','Quantity','Total','gross income']]

# %%
data.head()
# Out:
#    Gender      Payment  Unit price  Quantity    Total  gross income
# 0  Female  Credit card       54.84         3  172.746         8.226
# 1  Female      Ewallet       14.48         4   60.816         2.896
# 2    Male         Cash       25.51         4  107.142         5.102
# 3  Female         Cash       93.72         6  590.436        28.116
# 4  Female      Ewallet       40.30         2   84.630         4.030

# %%
sns.histplot(data=data,x = 'Total')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=data,x = 'Total',binwidth=150)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=data,x = 'Total',bins=30)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data,x = 'Total',bins=np.arange(0,1200,50))
plt.xticks(np.arange(0,1200,50))
plt.show()

# %%
sns.histplot(data=data,x='Total',kde=True)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=data,x='Total',hue='Payment',multiple='stack')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=data,x='Total',element='step')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=data,x='Total',element='poly')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=data,x='Total',hue='Payment',element='poly')
plt.show()

# %%
sns.histplot(data=data,x='Total',stat='probability')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Probability'>

# %%
data
# Out:
#      Gender      Payment  Unit price  Quantity    Total  gross income
# 0    Female  Credit card       54.84         3  172.746         8.226
# 1    Female      Ewallet       14.48         4   60.816         2.896
# 2      Male         Cash       25.51         4  107.142         5.102
# 3    Female         Cash       93.72         6  590.436        28.116
# 4    Female      Ewallet       40.30         2   84.630         4.030
# ..      ...          ...         ...       ...      ...           ...
# 995  Female  Credit card       56.56         5  296.940        14.140
# 996    Male      Ewallet       58.03         2  121.863         5.803
# 997    Male         Cash       31.84         1   33.432         1.592
# 998    Male         Cash       65.82         1   69.111         3.291
# 999  Female         Cash       88.34         7  649.299        30.919
#
# [1000 rows x 6 columns]

# %%
data= pd.read_excel('market.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0 Item_ID     Item_W      Item_Type    Item_MRP Outlet_ID  \
# 0           0   FDU32  21.027499   Baking Goods  197.352319    OUT046
# 1           1   NCT54  21.102371           Meat  148.250214    OUT035
# 2           2   FDW08  20.882263    Hard Drinks  205.465010    OUT035
# 3           3   FDJ22  21.050435  Starchy Foods  253.417583    OUT046
# 4           4   FDF47  21.247876   Baking Goods  240.871039    OUT035
#
#    Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# 0         2004       Small               Tier 2  2689.457781     2
# 1         1987       Small               Tier 1  3437.350375     1
# 2         1999       Small               Tier 3  3129.967268     3
# 3         1996       Small               Tier 1  1306.514376     1
# 4         1988       Small               Tier 3  1739.769829     3

# %%
matpiv = data.pivot_table(index='Outlet_Year',columns='Outlet_Size',values='Sales')

# %%
matpiv
# Out:
# Outlet_Size         High       Medium        Small
# Outlet_Year
# 1987         2015.037160  1792.973492  1917.302712
# 1988         1695.209700  1444.865311  1641.739583
# 1996         2265.268983  2272.371502  2219.790139
# 1997         2029.428925  1826.732664  1903.967543
# 1998         2306.542273  2279.666103  2233.775392
# 1999         2004.082749  1850.282194  1909.920236
# 2003         2261.028030  2158.063891  2190.118601
# 2004         1966.898730  1826.582596  1889.009488
# 2005         1935.238262  1010.230431  1215.937098
# 2007         2180.578424  2213.387887  2567.411612
# 2008         2169.407763  1900.378559  2201.448849
# 2009         1923.770187  1554.601061  1890.260032

# %%
plt.figure(figsize=(10,5))
sns.heatmap(matpiv)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Year'>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(matpiv,annot=True)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Year'>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(matpiv,annot=True,fmt='.0f')
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Year'>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(matpiv,annot=True,fmt='.0f',annot_kws={'size':13})
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Year'>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(matpiv,annot=True,fmt='.0f',annot_kws={'size':13},
           cmap='Greens')
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Year'>

# %%
data.corr()
# Out:
#              Unnamed: 0    Item_W  Item_MRP  Outlet_Year     Sales      Tier
# Unnamed: 0     1.000000 -0.611343  0.002811    -0.005616 -0.001327 -0.009457
# Item_W        -0.611343  1.000000 -0.022830     0.009632  0.000615  0.036061
# Item_MRP       0.002811 -0.022830  1.000000    -0.009837  0.014813 -0.026039
# Outlet_Year   -0.005616  0.009632 -0.009837     1.000000 -0.035701  0.184436
# Sales         -0.001327  0.000615  0.014813    -0.035701  1.000000 -0.045660
# Tier          -0.009457  0.036061 -0.026039     0.184436 -0.045660  1.000000

# %%
sns.heatmap(data.corr(),vmin=-1,vmax=1,center=0,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
data = pd.read_excel('mart_train_sample.xlsx')
data.columns = data.columns.str.lower()
data.head()
# Out:
#   item_id     item_w              item_type    item_mrp outlet_id  \
# 0   FDN27   9.437510            Snack Foods  195.313244    OUT046
# 1   FDW35   9.033762  Fruits and Vegetables   36.371449    OUT035
# 2   FDS28  20.884849           Frozen Foods   70.318167    OUT013
# 3   FDC09  19.976300            Snack Foods  121.723264    OUT018
# 4   FDX04  10.824812            Snack Foods  264.673302    OUT035
#
#    outlet_year outlet_size outlet_location_type        sales  tier
# 0         1997       Small               Tier 1   897.085562     1
# 1         2003       Small               Tier 2  1639.303513     2
# 2         2008       Small               Tier 1  2664.773737     1
# 3         2009      Medium               Tier 3   440.859593     3
# 4         2004       Small               Tier 1    29.807098     1

# %%
data['outlet_location_type'].unique()
# Out:
# array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object)

# %%
face = sns.FacetGrid(data,col='outlet_size')
face.map_dataframe(sns.histplot,x='sales')

# %%
sns.scatterplot(data=data,x='item_mrp',y='sales')
# Out:
# <AxesSubplot:xlabel='item_mrp', ylabel='sales'>

# %%
sns.scatterplot(data=data,x='item_mrp',y='sales',hue='outlet_size',s=100)
# Out:
# <AxesSubplot:xlabel='item_mrp', ylabel='sales'>
