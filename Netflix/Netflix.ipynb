# %%
import pandas as pd

# %%
data = pd.read_csv('Netflix.csv')

# %%
data.head(2) # إظهار أول سطرين
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.tail() # إظهار أخر خمسة أسطر
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape # شكل البيانات
# Out:
# (7789, 11)

# %%
data.size # عدد خلايا الجدول
# Out:
# 85679

# %%
data.columns # الأعمدة
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes # نوع كل  عامود
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
# الأسطر المتكررة
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# إسقاط هذه الأسطر
data.drop_duplicates(inplace = True)

# %%
# القيم المفقودة في كل عامود
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# توزع القيم الفقودة في البيانات 
plt.figure(figsize = (10,10))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# هل يوجد المسلسل المذك
data['Title'].isin(['House of Cards']).any()
# Out:
# True

# %%
# الأفلام المصنفة ضمن النوع المجدد
data[data['Type'].isin(['Dramas'])]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# إحضار سطر المسلسل المجدد
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# كل البيانات التى تحوى النوع المحدد
data[data['Type'].str.contains('Dramas')]
# Out:
#      Show_Id Category     Title           Director  \
# 0         s1  TV Show        3%                NaN
# 1         s2    Movie     07:19  Jorge Michel Grau
# 4         s5    Movie        21     Robert Luketic
# 5         s6  TV Show        46        Serdar Akar
# 7         s8    Movie       187     Kevin Reynolds
# ...      ...      ...       ...                ...
# 7776   s7775    Movie    Zodiac      David Fincher
# 7778   s7777    Movie  Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie       Zoo       Shlok Sharma
# 7784   s7783    Movie      Zozo        Josef Fares
# 7785   s7784    Movie    Zubaan        Mozez Singh
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# إضافة عامود في مكان غير مناسب
data['Date_time'] = pd.to_datetime(data['Release_Date'])

# %%
# إسقاط هذا العامود
data.drop('Date_time',axis=1,inplace =True)

# %%
# إضافة عامود يدل الفترة الزمنية
data.insert(loc=7,column='Date_time',value=pd.to_datetime(data['Release_Date']))

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date  Date_time Rating   Duration  \
# 0    August 14, 2020 2020-08-14  TV-MA  4 Seasons
# 1  December 23, 2016 2016-12-23  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# عدد المنتجات في كل سنة
df = data['Date_time'].dt.year.value_counts()
df
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_time, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df.index,y=df.values)
# Out:
# <AxesSubplot:>

# %%
df = data['Date_time'].dt.month_name().value_counts()
df
# Out:
# December     833
# October      785
# January      757
# November     738
# March        669
# September    619
# August       618
# April        601
# July         600
# May          543
# June         542
# February     472
# Name: Date_time, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=df.index,y=df.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2> groupby  </h2>
# <br>
#  <b>
#  أن العامود المختار لديه عناصر متكررة متواجدة في سطور مختلفة مرتبطة مع كامل السطر
#  وكل عنصر متكرر يكون مفتاح لبقية البيانات المرتبطة به المتواجدة في السطر ذاته
#  تضع هذه الدالة البيانات ضمن مجموعات متصلة بكل مفتاح لننفذ عليها عمليات محدد كالمتوسط
# وطبعا كل عامود يتمتع بصفات معينة لذلك نستطيع تحديد العامود المطلوب لتنفيذ العملية عليه

# %%
# العدد المنتج من كل فئة
data.groupby('Category')['Category'].count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['Year'] = data['Date_time'].dt.year

# %%
data['Month'] = data['Date_time'].dt.month

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date  Date_time Rating   Duration  \
# 0    August 14, 2020 2020-08-14  TV-MA  4 Seasons
# 1  December 23, 2016 2016-12-23  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description    Year  Month
# 0  In a future where the elite inhabit an island ...  2020.0    8.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0   12.0

# %%
# تصفية البيانات حسب الحاجة
data[(data['Category'] == 'Movie') & (data['Year']==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
# تصفية البيانات حسب الحاجة
data.query(" (Category == 'Movie' ) & (Year == 2020) ")
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
# تصفية البيانات حسب الحاجة
data[(data['Category'] == 'TV Show') & (data['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
# تصفية البيانات حسب الحاجة
data.query(" (Category == 'TV Show') & (Country == 'India')")['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
# معرفة الكتاب الأكثر كتابة 
df = data['Director'].value_counts().head(20)
df
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Lance Bangs                8
# Kunle Afolayan             8
# Ryan Polito                8
# Shannon Hartman            8
# Johnnie To                 8
# Quentin Tarantino          8
# Robert Rodriguez           8
# Omoni Oboli                7
# McG                        7
# Fernando Ayllón            7
# Name: Director, dtype: int64

# %%
plt.figure(figsize = (12,5))
sns.barplot(x=df.index,y=df.values)
plt.xticks(rotation = 90)
plt.show()

# %%
# تصفية البيانات حسب الحاجة
data[((data['Category'] == 'Movie') & (data['Type']=='Comedies' )) |\
     (data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
data.query(" (Category== 'Movie') & (Type == 'Comedies') & (Country == 'United Kingdom') ")
# Out:
#      Show_Id Category                                              Title  \
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2225   s2226    Movie                                  For Love or Money
# 4210   s4211    Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4213   s4214    Movie           Monty Python: Live at The Hollywood Bowl
# 4781   s4782    Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 4792   s4793    Movie                                     PATRICK (2019)
# 6109   s6109    Movie                            The Bad Education Movie
# 6947   s6946    Movie                                  The Trip to Spain
#
#                            Director  \
# 1368                  James Dearden
# 1650                    Tom Edmunds
# 2225                    Mark Murphy
# 4210                      Eric Idle
# 4213  Terry Hughes, Ian MacNaughton
# ...

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date  Date_time Rating   Duration  \
# 0    August 14, 2020 2020-08-14  TV-MA  4 Seasons
# 1  December 23, 2016 2016-12-23  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description    Year  Month
# 0  In a future where the elite inhabit an island ...  2020.0    8.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0   12.0

# %%
data[data['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Date_time, Rating, Duration, Type, Description, Year, Month]
# Index: []

# %% [raw]
# data[data['Cast'].str.contains('Tom Cruise')]

# %%
# إسقاط القيم الفقودة 
data_new = data.dropna()

# %%
data_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date  Date_time Rating Duration  \
# 1  December 23, 2016 2016-12-23  TV-MA   93 min
# 2  December 20, 2018 2018-12-20      R   78 min
#
#                                   Type  \
# 1         Dramas, International Movies
# 2  Horror Movies, International Movies
#
#                                          Description    Year  Month
# 1  After a devastating earthquake hits Mexico Cit...  2016.0   12.0
# 2  When an army recruit is found dead, his fellow...  2018.0   12.0

# %%
# إظهار أسطر المحرف المطلوب 
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date  Date_time Rating Duration                        Type  \
# 3860  January 1, 2020 2020-01-01      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019 2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year  Month
# 3860  Through chance, human action, past history and...  2020.0    1.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0    7.0

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
# تصفية البيانات حسب الحاجة
data[(data['Category'] == 'Movie') & (data['Rating']=='TV-14')].shape[0]
# Out:
# 1272

# %%
# عدد العناصر المكافئة للتصفية 
data[(data['Category'] == 'Movie') & (data['Rating']=='TV-14') &\
     (data['Country']=='Canada')].shape[0]
# Out:
# 11

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date  Date_time Rating   Duration  \
# 0    August 14, 2020 2020-08-14  TV-MA  4 Seasons
# 1  December 23, 2016 2016-12-23  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description    Year  Month
# 0  In a future where the elite inhabit an island ...  2020.0    8.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0   12.0

# %%
# عدد العناصر المكافئة للتصفية 
data[(data['Category']=='TV Show') & (data['Rating']=='R') & (data['Year'] >= 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date  Date_time Rating  Duration      Type  \
# 6437  April 25, 2019 2019-04-25      R  1 Season  TV Shows
#
#                                             Description    Year  Month
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0    4.0

# %%
data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data[['Min_sea','Unit']] = data['Duration'].str.split(' ',expand = True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date  Date_time Rating   Duration  \
# 0    August 14, 2020 2020-08-14  TV-MA  4 Seasons
# 1  December 23, 2016 2016-12-23  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description    Year  Month Min_sea  \
# 0  In a future where the elite inhabit an island ...  2020.0    8.0       4
# 1  After a devastating earthquake hits Mexico Cit...  2016.0   12.0      93
#
#       Unit
# 0  Seasons
# 1      min

# %%
data['Min_sea']=data['Min_sea'].astype(int)

# %%
data.groupby('Category')['Min_sea'].min()
# Out:
# Category
# Movie      3
# TV Show    1
# Name: Min_sea, dtype: int32

# %%
data.groupby('Category')['Min_sea'].max()
# Out:
# Category
# Movie      312
# TV Show     16
# Name: Min_sea, dtype: int32

# %%
data.groupby('Category')['Min_sea'].median()
# Out:
# Category
# Movie      98.0
# TV Show     1.0
# Name: Min_sea, dtype: float64

# %%
data.groupby('Category')['Min_sea'].max()
# Out:
# Category
# Movie      312
# TV Show     16
# Name: Min_sea, dtype: int32

# %%
# فصل البيانات 
data_tvshow = data[data['Category'] == 'TV Show' ]
data_movie = data[data['Category'] == 'Movie' ]

# %%
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#    Date_time Rating   Duration  \
# 0 2020-08-14  TV-MA  4 Seasons
# 5 2017-07-01  TV-MA   1 Season
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description    Year  Month  Min_sea  \
# 0  In a future where the elite inhabit an island ...  2020.0    8.0        4
# 5  A genetics professor experiments with a treatm...  2017.0    7.0        1
#
#       Unit
# 0  Seasons
# 5   Season

# %%
data_movie.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date  Date_time Rating Duration  \
# 1  December 23, 2016 2016-12-23  TV-MA   93 min
# 2  December 20, 2018 2018-12-20      R   78 min
#
#                                   Type  \
# 1         Dramas, International Movies
# 2  Horror Movies, International Movies
#
#                                          Description    Year  Month  Min_sea  \
# 1  After a devastating earthquake hits Mexico Cit...  2016.0   12.0       93
# 2  When an army recruit is found dead, his fellow...  2018.0   12.0       78
#
#   Unit
# 1  min
# 2  min

# %%
# تعداد المسلسلات بالنسبة الى الدولة المنتجة
data_tvshow['Country'].value_counts().head()
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: Country, dtype: int64

# %%
# تعداد الأفلام بالنسبة الى الدولة المنتجة
data_movie['Country'].value_counts().head()
# Out:
# United States     1850
# India              852
# United Kingdom     193
# Canada             118
# Spain               89
# Name: Country, dtype: int64

# %%
data_movie['Min_sea'].max()
# Out:
# 312

# %%
data_tvshow['Min_sea'].max()
# Out:
# 16

# %%
# أول خمسة منتجات
data.sort_values(by = 'Year').head()
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#            Release_Date  Date_time Rating  Duration  \
# ...

# %%
# أخر ثلاثة منتجات
data.sort_values(by = 'Year',ascending = False).head(3)
# Out:
#      Show_Id Category            Title                 Director  \
# 5564   s5564    Movie  Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie        Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show     Bling Empire                      NaN
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
#
#                                                 Country      Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia   January 1, 2021
# 5919                                      United States   January 1, 2021
# 980                                                 NaN  January 15, 2021
#
#       Date_time Rating  Duration  \
# 5564 2021-01-01  PG-13   128 min
# 5919 2021-01-01     PG    86 min
# 980  2021-01-15  TV-MA  1 Season
#
# ...

# %%
# تصفية البيانات حسب الحاجة
data[(data['Category'] == 'Movie') & (data['Type']=='Dramas') ]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# تصفية البيانات حسب الحاجة
data[(data['Category'] == 'TV Show') & (data['Type']=="Kids' TV") ]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
# تصفية البيانات حسب الحاجة
data[(data['Category'] == 'Movie') & (data['Type']=='Dramas')|\
     (data['Category'] == 'TV Show') & (data['Type']=="Kids' TV")
    ]
#  سوف تحدث مشكلة عند إستخدامها query هنا
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
